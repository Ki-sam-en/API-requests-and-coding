# %%
import requests
from requests.exceptions import HTTPError
import json
import locale
import datetime
import pandas

# %%
# Out:
# Got it

# %%
def datetime_func():
    today = datetime.date.today()
    print('using date: ', today)
    url = 'http://publication.pravo.gov.ru/api/Documents?Block&Category&SignatoryAuthorityId&DocumentDateFrom=' + str({today}) +'&NameNumberSearchType&Number'
    return url

try:
    response = requests.get(datetime_func())
    if response.status_code == 200:
        print('Got it')
except HTTPError as http_err:
    print(f'HTTP error occured: {http_err}')
except Exception as err:
    print(f'Other error occured: {err}')

response.text
# Out:
# usinf date:  2024-02-01
# Got it
# '{"items":[{"eoNumber":"0001202402010037","hasSvg":false,"zipFileLength":null,"publishDateShort":"2024-02-01T00:00:00","complexName":"Указ Президента Российской Федерации от 01.02.2024 № 82\\n \\"О внесении изменений в некоторые акты Президента Российской Федерации\\"","pagesCount":10,"pdfFileLength":812303,"jdRegNumber":null,"jdRegDate":null,"title":"Указ Президента Российской Федерации от 01.02.2024 № 82<br /> \\"О внесении изменений в некоторые акты Президента Российской Федерации\\"","viewDate":"01.02.2024","id":"d188702a-0109-4ce0-904b-64565102211e"},{"eoNumber":"0001202402010036","hasSvg":false,"zipFileLength":null,"publishDateShort":"2024-02-01T00:00:00","complexName":"Указ Президента Российской Федерации от 01.02.2024 № 81\\n \\"Об учреждении ордена \\"За доблестный труд\\"","pagesCount":9,"pdfFileLength":4486278,"jdRegNumber":null,"jdRegDate":null,"title":"Указ Президента Российской Федерации от 01.02.2024 № 81<br /> \\"Об учреждении ордена \\"За доблестный труд\\"","viewDate":"01.02.2024","id":"0668b3b4-2e3d-4713-aa2c-1db65a95f9ee"},{"eoNumber":"0001202402010001","hasSvg":false,"zipFileLength":null,"publishDateShort":"2024-02-01T00:00:00","complexName":"Постановление Конституционного Суда Российской Федерации от 31.01.2024 № 4-П\\nпо делу о проверке конституционности части первой статьи 53 Уголовного кодекса Российской Федерации в связи с жалобами граждан О.А.Балуковой и Ю.М.Чернигиной","pagesCount":24,"pdfFileLength":1276414,"jdRegNumber":null,"jdRegDate":null,"title":"Постановление Конституционного Суда Российской Федерации от 31.01.2024 № 4-П<br />по делу о проверке конституционности части первой статьи 53 Уголовного кодекса Российской Федерации в связи с жалобами граждан О.А.Балуковой и Ю.М.Чернигиной","viewDate":"01.02.2024","id":"555df32b-2033-4b1b-8258-3eaf830a8cad"},{"eoNumber":"0001202402010019","hasSvg":false,"zipFileLength":null,"publishDateShort":"2024-02-01T00:00:00","complexName":"Приказ Министерства внутренних дел Российской Федерации от 26.12.2023 № 1010\\n \\"О внесении изменений в приказ МВД России от 27 октября 2015 г. № 1010 \\"Об утверждении Порядка организации работы по обеспечению доступа к информации о деятельности Министерства внутренних дел Российской Федерации\\"","pagesCount":2,"pdfFileLength":105564,"jdRegNumber":"77062","jdRegDate":"2024-01-31T00:00:00","title":"Приказ Министерства внутренних дел Российской Федерации от 26.12.2023 № 1010<br /> \\"О внесении изменений в приказ МВД России от 27 октября 2015 г. № 1010 \\"Об утверждении Порядка организации работы по обеспечению доступа к информации о деятельности Министерства внутренних дел Российской Федерации\\"<br/>(Зарегистрирован 31.01.2024 № 77062)","viewDate":"01.02.2024","id":"eec0a775-b1d3-4b2a-9c94-427cef97803f"},{"eoNumber":"0001202402010035","hasSvg":false,"zipFileLength":null,"publishDateShort":"2024-02-01T00:00:00","complexName":"Приказ Министерства Российской Федерации по делам гражданской обороны, чрезвычайным ситуациям и ликвидации последствий стихийных бедствий от 22.01.2024 № 33\\n \\"Об утверждении Порядка подтверждения Министерством Российской Федерации по делам гражданской обороны, чрезвычайным ситуациям и ликвидации последствий стихийных бедствий наличия обстоятельств, характеризующих реальность угрозы возникновения техногенных, экологических катастроф и (или) наступления их последствий либо гибели людей на опасном объекте\\"","pagesCount":5,"pdfFileLength":404887,"jdRegNumber":"77069","jdRegDate":"2024-01-31T00:00:00","title":"Приказ Министерства Российской Федерации по делам гражданской обороны, чрезвычайным ситуациям и ликвидации последствий стихийных бедствий от 22.01.2024 № 33<br /> \\"Об утверждении Порядка подтверждения Министерством Российской Федерации по делам гражданской обороны, чрезвычайным ситуациям и ликвидации последствий стихийных бедствий наличия обстоятельств, характеризующих реальность угрозы возникновения техногенных, экологических катастроф и (или) наступления их последствий либо гибели людей на о ...

# %% [markdown]
# ### Параметры ссылки
# -----
# #### Ссылка на сайт:
# ##### 'http://publication.pravo.gov.ru'
#
# #### Сами параметры, которые я брала(есть и другие), чтобы получить ответ(все они необязательные):
# ##### key - description
# ##### Block - Код блока публикации
# ##### Category - Код категории принимающего органа
# ##### SignatoryAuthorityId - GUID Принявшего органа
# ##### NameNumberSearchType - Режим поиска по номеру НПА,  возможны следующие значения: 0 – точно, 1 – начинается с, 2 – заканчивается на, 3 – содержит
# ##### Number - Номер документа (НПА) – режим поиска, в соответствии с параметром «NumberSearchType»
# ##### DocumentDateFrom - типо от какой даты смотреть документы
#
# ##### Дату указала в формате дд.мм.гггг

# %%
response_text = []
response_text.append(response.text)
response_text
# Out:
# ['{"items":[{"eoNumber":"1900202401300002","hasSvg":false,"zipFileLength":null,"publishDateShort":"2024-01-30T00:00:00","complexName":"Постановление Правительства Республики Хакасия от 29.01.2024 № 54\\n \\"О внесении изменений в сводную бюджетную роспись республиканского бюджета Республики Хакасия в 2024 году\\"","pagesCount":4,"pdfFileLength":155739,"jdRegNumber":null,"jdRegDate":null,"title":"Постановление Правительства Республики Хакасия от 29.01.2024 № 54<br /> \\"О внесении изменений в сводную бюджетную роспись республиканского бюджета Республики Хакасия в 2024 году\\"","viewDate":"30.01.2024","id":"d97097ae-ce53-475b-b773-84eb36704f9f"},{"eoNumber":"2600202401300002","hasSvg":false,"zipFileLength":null,"publishDateShort":"2024-01-30T00:00:00","complexName":"Постановление Губернатора Ставропольского края от 29.01.2024 № 32\\n \\"О внесении изменений в постановление Губернатора Ставропольского края от 07 марта 2014 г. № 105 \\"О порядке организации и проведения опросов населения с использованием информационно-телекоммуникационных сетей и информационных технологий для оценки населением эффективности деятельности руководителей органов местного самоуправления муниципальных образований Ставропольского края, унитарных предприятий и учреждений, действующих на региональном и муниципальном уровнях, акционерных обществ, контрольный пакет акций которых находится в собственности Ставропольского края или муниципальной собственности муниципальных образований Ставропольского края, осуществляющих оказание услуг населению муниципальных образований Ставропольского края\\"","pagesCount":3,"pdfFileLength":89329,"jdRegNumber":null,"jdRegDate":null,"title":"Постановление Губернатора Ставропольского края от 29.01.2024 № 32<br /> \\"О внесении изменений в постановление Губернатора Ставропольского края от 07 марта 2014 г. № 105 \\"О порядке организации и проведения опросов населения с использованием информационно-телекоммуникационных сетей и информационных технологий для оценки населением эффективности деятельности руководителей органов местного самоуправления муниципальных образований Ставропольского края, унитарных предприятий и учреждений, действующих на региональном и муниципальном уровнях, акционерных обществ, контрольный пакет акций которых находится в собственности Ставропольского края или муниципальной собственности муниципальных образований Ставропольского края, осуществляющих оказание услуг населению муниципальных образований Ставропольского края\\"","viewDate":"30.01.2024","id":"e7bbed9f-6cd0-46cf-a975-1384969257b6"},{"eoNumber":"2600202401300001","hasSvg":false,"zipFileLength":null,"publishDateShort":"2024-01-30T00:00:00","complexName":"Постановление Губернатора Ставропольского края от 29.01.2024 № 31\\n \\"Об установлении ограничительных мероприятий (карантина) на территориях Петровского и Грачевского районов Ставропольского края\\"","pagesCount":3,"pdfFileLength":77967,"jdRegNumber":null,"jdRegDate":null,"title":"Постановление Губернатора Ставропольского края от 29.01.2024 № 31<br /> \\"Об установлении ограничительных мероприятий (карантина) на территориях Петровского и Грачевского районов Ставропольского края\\"","viewDate":"30.01.2024","id":"c0c154f5-7ba4-43f8-8f6d-d432a8388b78"},{"eoNumber":"2600202401300004","hasSvg":false,"zipFileLength":null,"publishDateShort":"2024-01-30T00:00:00","complexName":"Постановление Правительства Ставропольского края от 29.01.2024 № 36-п\\n \\"О внесении изменений в постановление Правительства Ставропольского края от 26 декабря 2023 г. № 794-п \\"Об утверждении государственной программы Ставропольского края \\"Развитие жилищно-коммунального хозяйства, защита населения и территории от чрезвычайных ситуаций\\"","pagesCount":2,"pdfFileLength":86396,"jdRegNumber":null,"jdRegDate":null,"title":"Постановление Правительства Ставропольского края от 29.01.2024 № 36-п<br /> \\"О внесении изменений в постановление Правительства Ставропольского края от 26 декабря 2023 г. № 794-п \\"Об утверждении государственн ...

# %%
# это я вывела потому что так нужно было
locale.getpreferredencoding()
# Out:
# 'utf-8'

# %%
# with open('API pravo gov 1.json', 'w', encoding = 'utf-8') as outfile:
    #json.dump(response_text, outfile, ensure_ascii=False)

# %% [markdown]
# #### что потом:
# ##### чтобы получить доступ ко всей информации документа, а не только о его номере, дате публикации и полном заголовке, можно сделать по идее так:
# ##### к ссылке: 'http://publication.pravo.gov.ru/document/' добавить eoNumber дока, который приходит в ответе с запросом, который я оформляла выше
